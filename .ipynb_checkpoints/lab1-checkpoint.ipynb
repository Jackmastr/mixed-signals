# %%
# Hello Lab 1!

# %%
import matplotlib.pylab as pl
import numpy as np
import ugradio
# %matplotlib inline

# %%
arr = ugradio.pico.read_socket("2V")

# %%
print arr
# Out:
# [-15104   1024  15360 ...,    256 -15104  -9728]

# %%
print arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-bb090780799d> in <module>()
# ----> 1 print arr
#
# NameError: name 'arr' is not defined

# %%
x = np.linspace(0, 3.2, 200)
pl.plot(x, arr[:200], 'k.-')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe615c0ea10>,
#  <matplotlib.lines.Line2D at 0x7fe615c0ec90>]

# %%
1/31.25 * 10**(-6) * 100
# Out:
# 3.2000000000000003e-06

# %%
i = 1

# %%
filename = "sample_" + str(i) + ".npy"
i+=1
print filename
arr = ugradio.pico.read_socket("2V", 10)
print arr
np.save(filename, arr)
print np.load(filename)
arr_plot = np.load(filename)
pl.figure(i, figsize=(20,10))
pl.plot(arr_plot[:256], 'k.-')
# Out:
# sample_1.npy
# [ 13312   5376  -4864 ..., -14848 -16128 -11008]
# [ 13312   5376  -4864 ..., -14848 -16128 -11008]

# %%
i = 1
while i < 10:
    filename = "sample_" + str(i) + ".npy"
    arr_plot = np.load(filename)
    pl.figure(i, figsize=(20,10))
    pl.plot(arr_plot[:256], 'k.-')
    pl.figure(i+9, figsize=(20,10))
    pl.plot(arr_plot[:32], 'b.-')
    i += 1

# %%
N = 256
i = 1
chan = np.linspace((-6.25/2),(1 - 2/N) * (6.25/2),num=N,endpoint=False)
while i < 10:
    filename = "sample_" + str(i) + ".npy"
    arr_plot = np.load(filename)
    pl.figure(i, figsize=(20,10))
    fourier_test = ugradio.dft.dft(arr_plot[:N])
    fourier_test = np.abs(fourier_test)**2
    pl.plot(chan, fourier_test, 'k.-')
    i += 1

# %%
N = 128
chan = np.linspace((-6.25/2),(1 - 2/N) * (6.25/2),num=N,endpoint=False)
i = 1
while i < 10:
    filename = "sample_" + str(i) + ".npy"
    arr_plot = np.load(filename)
    pl.figure(i, figsize=(20,10))
    voltage_test = ugradio.dft.dft(arr_plot[:N])
    real = np.real(voltage_test)
    imag = np.imag(voltage_test)
    pl.plot(chan, real, 'k.-')
    pl.plot(chan, imag, 'r.--')
    i += 1

# %%
N = 256
chan = np.linspace((-6.25/2),(1 - 2/N) * (6.25/2),num=N,endpoint=False)
arr_plot = np.load("sample_2.npy")
pl.figure(1, figsize=(20,10))
voltage = ugradio.dft.dft(arr_plot[:N])
power = np.abs(voltage)**2
inv_fourier = ugradio.dft.dft(power)
inv_fourier = np.abs(inv_fourier)
pl.plot(chan, inv_fourier, 'k.-')

ACF = np.correlate(inv_fourier, inv_fourier, mode="full")
pl.figure(2, figsize=(20,10))
pl.plot( ACF, 'k.-')

# %%
#3.4 - Leakage Power

# %%
# 3.7 - Fourier Transforms of Noise
arr = ugradio.pico.read_socket("50mV")
print arr
pl.figurefigsize=(20,10)
pl.plot(arr[:256], 'k.-')
pl.hist(arr[:256], bins=)
# Out:
# [ -2560 -15104  13568 ...,  -7680  11776   5632]
# (array([  2.,   1.,   1.,   3.,   1.,   6.,   6.,   6.,   9.,   8.,   4.,
#          14.,  15.,  16.,  25.,  13.,  22.,  20.,  12.,   9.,  13.,  10.,
#          11.,   7.,   7.,   3.,   4.,   4.,   1.,   1.,   1.,   1.]),
#  array([-24064., -22520., -20976., -19432., -17888., -16344., -14800.,
#         -13256., -11712., -10168.,  -8624.,  -7080.,  -5536.,  -3992.,
#          -2448.,   -904.,    640.,   2184.,   3728.,   5272.,   6816.,
#           8360.,   9904.,  11448.,  12992.,  14536.,  16080.,  17624.,
#          19168.,  20712.,  22256.,  23800.,  25344.]),
#  <a list of 32 Patch objects>)
